# %% [markdown]
# Now we will
# - Create a ML model
# - Use fast api to create an endpoint for interation with this model
# - Use streamlit for frontend to communicate with backend

# %% [markdown]
# Flow chart:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Create ML model --> Export it as model.pkl
# - Create endpoint "/predict" with POST method (User will give request body and model will do the inference)
# - Create frontend to give user interface
